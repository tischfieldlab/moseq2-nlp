# %%
import pandas as pd
import numpy as np
import seaborn as sns
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# # rOT

# %%
features = pd.read_csv('rOT/features.csv').to_numpy()
labels = pd.read_csv('rOT/labels.csv').to_numpy()

# %%
classes = np.unique(labels)
# colors = {'24hrs meloxicam':'r', '24hrs saline':'g', '4hrs carrageenan':'b', 'baseline':'c', 'baseline meloxicam':'k'}
colors = {'24hrs meloxicam':"#58d68d", '24hrs saline':"#f7dc6f", '4hrs carrageenan':"#e59866", 'baseline':"#5d6d7e", 'baseline meloxicam':"#d2b4de"}


meloxicam24h = mpatches.Patch(color="#58d68d", label='24hrs meloxicam')
saline24h = mpatches.Patch(color="#f7dc6f", label='24hrs saline')
carrageenan = mpatches.Patch(color="#e59866", label='4hrs carrageenan')
baseline = mpatches.Patch(color="#5d6d7e", label='baseline')
baselineMeloxicam =  mpatches.Patch(color="#d2b4de", label='baseline meloxicam')

# %%
c = []
for label in labels:
    if label[0] in colors:
        c.append(colors[label[0]])

# %%
pca = PCA(n_components=2)
pca.fit(features)
pca_f = pca.transform(features)

fig = plt.figure(figsize=(6,5))
ax = plt.axes()

ax.scatter(pca_f[:, 0], pca_f[:, 1], s=75,c=c, cmap=plt.cm.nipy_spectral)

fig.tight_layout(h_pad=2)
title = fig.suptitle('Transitions PCA rOT 2D', size='16')
fig.subplots_adjust(top=0.88)
legend = fig.legend(handles=[meloxicam24h,saline24h,carrageenan,baseline,baselineMeloxicam],bbox_to_anchor=(1.04,0.5), loc="center left")
fig.savefig('Transitions_PCA_rOT_2D.png',bbox_extra_artists=(legend,title), bbox_inches='tight')

# %%
pca = PCA(n_components=3)
pca.fit(features)
pca_f = pca.transform(features)

fig = plt.figure(1,figsize=(6,5))
ax = Axes3D(fig, rect=[0, 0, 0.95, 1], elev=48, azim=134)

ax.scatter(pca_f[:, 0], pca_f[:, 1],pca_f[:, 2],s=75, c=c, cmap=plt.cm.nipy_spectral )

fig.tight_layout(h_pad=2)
title = fig.suptitle('Transitions PCA rOT 3D', size='16')
fig.subplots_adjust(top=0.88)
legend = fig.legend(handles=[meloxicam24h,saline24h,carrageenan,baseline,baselineMeloxicam],bbox_to_anchor=(1.04,0.5), loc="center left")
fig.savefig('Transitions_PCA_rOT_3D.png',bbox_extra_artists=(legend,title), bbox_inches='tight')
# Out:
# /var/folders/9g/q8v5qs7j4rbb00lwj8dwq4fw0000gn/T/ipykernel_19219/2262123957.py:6: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig, rect=[0, 0, 0.95, 1], elev=48, azim=134)
# /var/folders/9g/q8v5qs7j4rbb00lwj8dwq4fw0000gn/T/ipykernel_19219/2262123957.py:10: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout(h_pad=2)

# %% [markdown]
# # rST

# %%
features = pd.read_csv('rST/features.csv').to_numpy()
labels = pd.read_csv('rST/labels.csv').to_numpy()

# %%
pca = PCA(n_components=2)
pca.fit(features)
pca_f = pca.transform(features)

fig = plt.figure(figsize=(6,5))
ax = plt.axes()


ax.scatter(pca_f[:, 0], pca_f[:, 1], s=75,c=c, cmap=plt.cm.nipy_spectral_r)
fig.tight_layout(h_pad=2)
title = fig.suptitle('Transitions PCA rST 2D', size='16')
fig.subplots_adjust(top=0.88)
legend = fig.legend(handles=[meloxicam24h,saline24h,carrageenan,baseline,baselineMeloxicam],bbox_to_anchor=(1.04,0.5), loc="center left")
fig.savefig('Transitions_PCA_rST_2D.png',bbox_extra_artists=(legend,title), bbox_inches='tight')

# %%
pca = PCA(n_components=3)
pca.fit(features)
pca_f = pca.transform(features)

fig = plt.figure(1,figsize=(6,5))
ax = Axes3D(fig, rect=[0, 0, 0.95, 1], elev=48, azim=134)

ax.scatter(pca_f[:, 0], pca_f[:, 1],pca_f[:, 2],s=75, c=c, cmap=plt.cm.nipy_spectral_r)

fig.tight_layout(h_pad=2)
title = fig.suptitle('Transitions PCA rST 3D', size='16')
fig.subplots_adjust(top=0.88)
legend = fig.legend(handles=[meloxicam24h,saline24h,carrageenan,baseline,baselineMeloxicam],bbox_to_anchor=(1.04,0.5), loc="center left")
fig.savefig('Transitions_PCA_rST_3D.png',bbox_extra_artists=(legend,title), bbox_inches='tight')
# Out:
# /var/folders/9g/q8v5qs7j4rbb00lwj8dwq4fw0000gn/T/ipykernel_19219/806662566.py:6: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig, rect=[0, 0, 0.95, 1], elev=48, azim=134)
# /var/folders/9g/q8v5qs7j4rbb00lwj8dwq4fw0000gn/T/ipykernel_19219/806662566.py:10: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout(h_pad=2)

# %% [markdown]
# # gOT

# %%
features = pd.read_csv('gOT/features.csv').to_numpy()
labels = pd.read_csv('gOT/labels.csv').to_numpy()

# %%
pca = PCA(n_components=2)
pca.fit(features)
pca_f = pca.transform(features)

fig = plt.figure(figsize=(6,5))
ax = plt.axes()


ax.scatter(pca_f[:, 0], pca_f[:, 1],s=75, c=c, cmap=plt.cm.nipy_spectral )

fig.tight_layout(h_pad=2)
title = fig.suptitle('Transitions PCA gOT 2D', size='16')
fig.subplots_adjust(top=0.88)
legend = fig.legend(handles=[meloxicam24h,saline24h,carrageenan,baseline,baselineMeloxicam],bbox_to_anchor=(1.04,0.5), loc="center left")
fig.savefig('Transitions_PCA_gOT_2D.png',bbox_extra_artists=(legend,title), bbox_inches='tight')

# %%
pca = PCA(n_components=3)
pca.fit(features)
pca_f = pca.transform(features)

fig = plt.figure(1,figsize=(6,5))
ax = Axes3D(fig, rect=[0, 0, 0.95, 1], elev=48, azim=134)

ax.scatter(pca_f[:, 0], pca_f[:, 1],pca_f[:, 2],s=75, c=c, cmap=plt.cm.nipy_spectral )

fig.tight_layout(h_pad=2)
title = fig.suptitle('Transitions PCA gOT 3D', size='16')
fig.subplots_adjust(top=0.88)
legend = fig.legend(handles=[meloxicam24h,saline24h,carrageenan,baseline,baselineMeloxicam],bbox_to_anchor=(1.04,0.5), loc="center left")
fig.savefig('Transitions_PCA_gOT_3D.png',bbox_extra_artists=(legend,title), bbox_inches='tight')
# Out:
# /var/folders/9g/q8v5qs7j4rbb00lwj8dwq4fw0000gn/T/ipykernel_19219/1030517317.py:6: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig, rect=[0, 0, 0.95, 1], elev=48, azim=134)
# /var/folders/9g/q8v5qs7j4rbb00lwj8dwq4fw0000gn/T/ipykernel_19219/1030517317.py:10: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout(h_pad=2)

# %% [markdown]
# # gST

# %%
features = pd.read_csv('gST/features.csv').to_numpy()
labels = pd.read_csv('gST/labels.csv').to_numpy()

# %%
pca = PCA(n_components=2)
pca.fit(features)
pca_f = pca.transform(features)

fig = plt.figure(figsize=(6,5))
ax = plt.axes()


ax.scatter(pca_f[:, 0], pca_f[:, 1],s=75, c=c, cmap=plt.cm.nipy_spectral )

fig.tight_layout(h_pad=2)
title = fig.suptitle('Transitions PCA gST 2D', size='16')
fig.subplots_adjust(top=0.88)
legend = fig.legend(handles=[meloxicam24h,saline24h,carrageenan,baseline,baselineMeloxicam],bbox_to_anchor=(1.04,0.5), loc="center left")
fig.savefig('Transitions_PCA_gST_2D.png',bbox_extra_artists=(legend,title), bbox_inches='tight')

# %%
pca = PCA(n_components=3)
pca.fit(features)
pca_f = pca.transform(features)

fig = plt.figure(1,figsize=(6,5))
ax = Axes3D(fig, rect=[0, 0, 0.95, 1], elev=48, azim=134)

ax.scatter(pca_f[:, 0], pca_f[:, 1],pca_f[:, 2],s=75, c=c, cmap=plt.cm.nipy_spectral )

fig.tight_layout(h_pad=2)
title = fig.suptitle('Transitions PCA gST 3D', size='16')
fig.subplots_adjust(top=0.88)
legend = fig.legend(handles=[meloxicam24h,saline24h,carrageenan,baseline,baselineMeloxicam],bbox_to_anchor=(1.04,0.5), loc="center left")
fig.savefig('Transitions_PCA_gST_3D.png',bbox_extra_artists=(legend,title), bbox_inches='tight')
# Out:
# /var/folders/9g/q8v5qs7j4rbb00lwj8dwq4fw0000gn/T/ipykernel_19219/828592428.py:6: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig, rect=[0, 0, 0.95, 1], elev=48, azim=134)
# /var/folders/9g/q8v5qs7j4rbb00lwj8dwq4fw0000gn/T/ipykernel_19219/828592428.py:10: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout(h_pad=2)
