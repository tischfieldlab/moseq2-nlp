# %%
import pandas as pd
import numpy as np
import seaborn as sns
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.patches as mpatches

# %% [markdown]
# # rOT

# %%
features = pd.read_csv('rOT/features.csv').to_numpy()
labels = pd.read_csv('rOT/labels.csv').to_numpy()

# %%
classes = np.unique(labels)
# colors = {'24hrs meloxicam':'r', '24hrs saline':'g', '4hrs carrageenan':'b', 'baseline':'c', 'baseline meloxicam':'k'}
colors = {'24hrs meloxicam':"#58d68d", '24hrs saline':"#f7dc6f", '4hrs carrageenan':"#e59866", 'baseline':"#5d6d7e", 'baseline meloxicam':"#d2b4de"}


meloxicam24h = mpatches.Patch(color="#58d68d", label='24hrs meloxicam')
saline24h = mpatches.Patch(color="#f7dc6f", label='24hrs saline')
carrageenan = mpatches.Patch(color="#e59866", label='4hrs carrageenan')
baseline = mpatches.Patch(color="#5d6d7e", label='baseline')
baselineMeloxicam =  mpatches.Patch(color="#d2b4de", label='baseline meloxicam')

# %%
c = []
for label in labels:
    if label[0] in colors:
        c.append(colors[label[0]])

# %%
pca = PCA(n_components=2)
pca.fit(features)
pca_f = pca.transform(features)

fig = plt.figure(figsize=(6,5))
ax = plt.axes()


ax.scatter(pca_f[:, 0], pca_f[:, 1],s=75, c=c, cmap=plt.cm.nipy_spectral)

fig.tight_layout(h_pad=2)
title = fig.suptitle('Usages PCA rOT 2D', size='16')
fig.subplots_adjust(top=0.88)
legend = fig.legend(handles=[meloxicam24h,saline24h,carrageenan,baseline,baselineMeloxicam],bbox_to_anchor=(1.04,0.5), loc="center left")
fig.savefig('Usages_PCA_rOT_2D.png',bbox_extra_artists=(legend,title), bbox_inches='tight')

# %%
pca = PCA(n_components=3)
pca.fit(features)
pca_f = pca.transform(features)

fig = plt.figure(1,figsize=(6,5))
ax = Axes3D(fig, rect=[0, 0, 0.95, 1], elev=48, azim=134)

ax.scatter(pca_f[:, 0], pca_f[:, 1],pca_f[:, 2],s=75, c=c, cmap=plt.cm.nipy_spectral)

fig.tight_layout(h_pad=2)
title = fig.suptitle('Usages PCA rOT 3D', size='16')
fig.subplots_adjust(top=0.88)
legend = fig.legend(handles=[meloxicam24h,saline24h,carrageenan,baseline,baselineMeloxicam],bbox_to_anchor=(1.04,0.5), loc="center left")
fig.savefig('Usages_PCA_rOT_3D.png',bbox_extra_artists=(legend,title), bbox_inches='tight')
# Out:
# /var/folders/9g/q8v5qs7j4rbb00lwj8dwq4fw0000gn/T/ipykernel_19303/589218043.py:6: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig, rect=[0, 0, 0.95, 1], elev=48, azim=134)
# /var/folders/9g/q8v5qs7j4rbb00lwj8dwq4fw0000gn/T/ipykernel_19303/589218043.py:10: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout(h_pad=2)

# %% [markdown]
# # rST

# %%
features = pd.read_csv('rST/features.csv').to_numpy()
labels = pd.read_csv('rST/labels.csv').to_numpy()

# %%
pca = PCA(n_components=2)
pca.fit(features)
pca_f = pca.transform(features)

fig = plt.figure(figsize=(6,5))
ax = plt.axes()


ax.scatter(pca_f[:, 0], pca_f[:, 1], s=75,c=c, cmap=plt.cm.nipy_spectral_r)
fig.tight_layout(h_pad=2)
title = fig.suptitle('Usages PCA rST 2D', size='16')
fig.subplots_adjust(top=0.88)
legend = fig.legend(handles=[meloxicam24h,saline24h,carrageenan,baseline,baselineMeloxicam],bbox_to_anchor=(1.04,0.5), loc="center left")
fig.savefig('Usages_PCA_rST_2D.png',bbox_extra_artists=(legend,title), bbox_inches='tight')

# %%
pca = PCA(n_components=3)
pca.fit(features)
pca_f = pca.transform(features)

fig = plt.figure(1,figsize=(6,5))
ax = Axes3D(fig, rect=[0, 0, 0.95, 1], elev=48, azim=134)

ax.scatter(pca_f[:, 0], pca_f[:, 1],pca_f[:, 2],s=75, c=c, cmap=plt.cm.nipy_spectral_r)

fig.tight_layout(h_pad=2)
title = fig.suptitle('Usages PCA rST 3D', size='16')
fig.subplots_adjust(top=0.88)
legend = fig.legend(handles=[meloxicam24h,saline24h,carrageenan,baseline,baselineMeloxicam],bbox_to_anchor=(1.04,0.5), loc="center left")
fig.savefig('Usages_PCA_rST_3D.png',bbox_extra_artists=(legend,title), bbox_inches='tight')
# Out:
# /var/folders/9g/q8v5qs7j4rbb00lwj8dwq4fw0000gn/T/ipykernel_19303/1502071758.py:6: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig, rect=[0, 0, 0.95, 1], elev=48, azim=134)
# /var/folders/9g/q8v5qs7j4rbb00lwj8dwq4fw0000gn/T/ipykernel_19303/1502071758.py:10: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout(h_pad=2)

# %% [markdown]
# # gOT

# %%
features = pd.read_csv('gOT/features.csv').to_numpy()
labels = pd.read_csv('gOT/labels.csv').to_numpy()

# %%
pca = PCA(n_components=2)
pca.fit(features)
pca_f = pca.transform(features)

fig = plt.figure(figsize=(6,5))
ax = plt.axes()


ax.scatter(pca_f[:, 0], pca_f[:, 1], c=c, cmap=plt.cm.nipy_spectral, edgecolor="k")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/aishwaryaharpale/tischfield-lab/moseq2_nlp_usages/examine-PCA.ipynb Cell 14' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/aishwaryaharpale/tischfield-lab/moseq2_nlp_usages/examine-PCA.ipynb#ch0000013?line=0'>1</a> pca = PCA(n_components=2)
# ----> <a href='vscode-notebook-cell:/Users/aishwaryaharpale/tischfield-lab/moseq2_nlp_usages/examine-PCA.ipynb#ch0000013?line=1'>2</a> pca.fit(features)
#       <a href='vscode-notebook-cell:/Users/aishwaryaharpale/tischfield-lab/moseq2_nlp_usages/examine-PCA.ipynb#ch0000013?line=2'>3</a> pca_f = pca.transform(features)
#       <a href='vscode-notebook-cell:/Users/aishwaryaharpale/tischfield-lab/moseq2_nlp_usages/examine-PCA.ipynb#ch0000013?line=4'>5</a> fig = plt.figure(figsize=(6,5))
#
# File ~/opt/anaconda3/envs/moseq2-nlp/lib/python3.8/site-packages/sklearn/decomposition/_pca.py:359, in PCA.fit(self, X, y)
#     <a href='file:///Users/aishwaryaharpale/opt/anaconda3/envs/moseq2-nlp/lib/python3.8/site-packages/sklearn/decomposition/_pca.py?line=342'>343</a> def fit(self, X, y=None):
#     <a href='file:///Users/aishwaryaharpale/opt/anaconda3/envs/moseq2-nlp/lib/python3.8/site-packages/sklearn/decomposition/_pca.py?line=343'>344</a>     """Fit the model with X.
#     <a href='file:///Users/aishwaryaharpale/opt/anaconda3/envs/moseq2-nlp/lib/python3.8/site-packages/sklearn/decomposition/_pca.py?line=344'>345</a>
#     <a href='file:///Users/aishwaryaharpale/opt/anaconda3/envs/moseq2-nlp/lib/python3.8/site-packages/sklearn/decomposition/_pca.py?line=345'>346</a>     Parameters
#    (...)
#     <a href='file:///Users/aishwaryaharpale/opt/anaconda3/envs/moseq2-nlp/lib/python3.8/site-packages/sklearn/decomposition/_pca.py?line=356'>357</a>         Returns the instance itself.
#     <a href='file:///Users/aishwaryaharpale/opt/anaconda3/envs/moseq2-nlp/lib/python3.8/site-packages/sklearn/decomposition/_pca.py?line=357'>358</a>     """
# --> <a href='file:///Users/aishwaryaharpale/opt/anaconda3/envs/moseq2-nlp/lib/python3.8/site-packages/sklearn/decomposition/_pca.py?line=358'>359</a>     self._fit(X)
#     <a href='file:///Users/aishwaryaharpale/opt/anaconda3/envs/moseq2-nlp/lib/python3.8/site-packages/sklearn/decomposition/_pca.py?line=359'>360</a>     return self
#
# File ~/opt/anaconda3/envs/moseq2-nlp/lib/python3.8/site-packages/sklearn/decomposition/_pca.py:404, in PCA._fit(self, X)
#     <a href='file:///Users/aishwaryaharpale/opt/anaconda3/envs/moseq2-nlp/lib/python3.8/site-packages/sklearn/decomposition/_pca.py?line=399'>400</a> if issparse(X):
#     <a href='file:///Users/aishwaryaharpale/opt/anaconda3/envs/moseq2-nlp/lib/python3.8/site-packages/sklearn/decomposition/_pca.py?line=400'>401</a>     raise TypeError('PCA does not support sparse input. See '
#     <a href='file:///Users/aishwaryaharpale/opt/anaconda3/envs/moseq2-nlp/lib/python3.8/site-packages/sklearn/decomposition/_pca.py?line=401'>402</a>                     'TruncatedSVD for a possible alternative.')
# --> <a href='file:///Users/aishwaryaharpale/opt/anaconda3/envs/moseq2-nlp/lib/python3.8/site-packages/sklearn/decomposition/_pca.py?line=403'>404</a> X = self._validate_data(X, dtype=[np.float64, np.float32],
#     <a href='file:///Users/aishwaryaharpale/opt/anaconda3/envs/moseq2-nlp/lib/python3.8/site-packages/sklearn/decomposition/_pca.py?line=404'>405</a>                         ensure_2d=True, copy=self.copy)
#     <a href='file:///Users/aishwaryaharpale/opt/anaconda3/envs/moseq2-nlp/lib/python3.8/site-packages/sklearn/decomposition/_pca.py?line=406'>407</a> # Handle n_components==None
#     <a href='file:///Users/aishwaryaharpale/opt/anaconda3/envs/moseq2-nlp/lib/python3.8/site-packages/sklearn/decomposition/_pca.py?line=407'>408</a> if self.n_components is None:
#
# File ~/opt/anaconda3/envs/moseq2-nlp/lib/python3.8/site-packages/sklearn/base.py:421, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     <a href='file:///Users/aishwaryaharpale/opt/anaconda3/envs/moseq2-nlp/lib/python3.8/site-packages/sklearn/base.py?line=418'>419</a>     out = X
#     <a href='file:///Users/aishwaryaharpale/opt/anaconda3/envs/moseq2-nlp/lib/python3.8/site-packages/sklearn/base.py?line=419'>420</a> elif isinstance(y, str) and y == 'no_validation':
# --> <a href='file:///Users/aishwaryaharpale/opt/anaconda3/envs/moseq2-nlp/lib/python3.8/site-packages/sklearn/base.py?line=420'>421</a>     X = check_array(X, **check_params)
#     <a href='file:///Users/aishwaryaharpale/opt/anaconda3/envs/moseq2-nlp/lib/python3.8/site-packages/sklearn/base.py?line=421'>422</a>     out = X
#     <a href='file:///Users/aishwaryaharpale/opt/anaconda3/envs/moseq2-nlp/lib/python3.8/site-packages/sklearn/base.py?line=422'>423</a> else:
#
# File ~/opt/anaconda3/envs/moseq2-nlp/lib/python3.8/site-packages/sklearn/utils/validation.py:63, in _deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      <a href='file:///Users/aishwaryaharpale/opt/anaconda3/envs/moseq2-nlp/lib/python3.8/site-packages/sklearn/utils/validation.py?line=60'>61</a> extra_args = len(args) - len(all_args)
#      <a href='file:///Users/aishwaryaharpale/opt/anaconda3/envs/moseq2-nlp/lib/python3.8/site-packages/sklearn/utils/validation.py?line=61'>62</a> if extra_args <= 0:
# ---> <a href='file:///Users/aishwaryaharpale/opt/anaconda3/envs/moseq2-nlp/lib/python3.8/site-packages/sklearn/utils/validation.py?line=62'>63</a>     return f(*args, **kwargs)
#      <a href='file:///Users/aishwaryaharpale/opt/anaconda3/envs/moseq2-nlp/lib/python3.8/site-packages/sklearn/utils/validation.py?line=64'>65</a> # extra_args > 0
#      <a href='file:///Users/aishwaryaharpale/opt/anaconda3/envs/moseq2-nlp/lib/python3.8/site-packages/sklearn/utils/validation.py?line=65'>66</a> args_msg = ['{}={}'.format(name, arg)
#      <a href='file:///Users/aishwaryaharpale/opt/anaconda3/envs/moseq2-nlp/lib/python3.8/site-packages/sklearn/utils/validation.py?line=66'>67</a>             for name, arg in zip(kwonly_args[:extra_args],
#      <a href='file:///Users/aishwaryaharpale/opt/anaconda3/envs/moseq2-nlp/lib/python3.8/site-packages/sklearn/utils/validation.py?line=67'>68</a>                                  args[-extra_args:])]
#
# File ~/opt/anaconda3/envs/moseq2-nlp/lib/python3.8/site-packages/sklearn/utils/validation.py:673, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     <a href='file:///Users/aishwaryaharpale/opt/anaconda3/envs/moseq2-nlp/lib/python3.8/site-packages/sklearn/utils/validation.py?line=670'>671</a>         array = array.astype(dtype, casting="unsafe", copy=False)
#     <a href='file:///Users/aishwaryaharpale/opt/anaconda3/envs/moseq2-nlp/lib/python3.8/site-packages/sklearn/utils/validation.py?line=671'>672</a>     else:
# --> <a href='file:///Users/aishwaryaharpale/opt/anaconda3/envs/moseq2-nlp/lib/python3.8/site-packages/sklearn/utils/validation.py?line=672'>673</a>         array = np.asarray(array, order=order, dtype=dtype)
#     <a href='file:///Users/aishwaryaharpale/opt/anaconda3/envs/moseq2-nlp/lib/python3.8/site-packages/sklearn/utils/validation.py?line=673'>674</a> except ComplexWarning as complex_warning:
#     <a href='file:///Users/aishwaryaharpale/opt/anaconda3/envs/moseq2-nlp/lib/python3.8/site-packages/sklearn/utils/validation.py?line=674'>675</a>     raise ValueError("Complex data not supported\n"
#     <a href='file:///Users/aishwaryaharpale/opt/anaconda3/envs/moseq2-nlp/lib/python3.8/site-packages/sklearn/utils/validation.py?line=675'>676</a>                      "{}\n".format(array)) from complex_warning
#
# File ~/opt/anaconda3/envs/moseq2-nlp/lib/python3.8/site-packages/numpy/core/_asarray.py:83, in asarray(a, dtype, order)
#      <a href='file:///Users/aishwaryaharpale/opt/anaconda3/envs/moseq2-nlp/lib/python3.8/site-packages/numpy/core/_asarray.py?line=13'>14</a> @set_module('numpy')
#      <a href='file:///Users/aishwaryaharpale/opt/anaconda3/envs/moseq2-nlp/lib/python3.8/site-packages/numpy/core/_asarray.py?line=14'>15</a> def asarray(a, dtype=None, order=None):
#      <a href='file:///Users/aishwaryaharpale/opt/anaconda3/envs/moseq2-nlp/lib/python3.8/site-packages/numpy/core/_asarray.py?line=15'>16</a>     """Convert the input to an array.
#      <a href='file:///Users/aishwaryaharpale/opt/anaconda3/envs/moseq2-nlp/lib/python3.8/site-packages/numpy/core/_asarray.py?line=16'>17</a>
#      <a href='file:///Users/aishwaryaharpale/opt/anaconda3/envs/moseq2-nlp/lib/python3.8/site-packages/numpy/core/_asarray.py?line=17'>18</a>     Parameters
#    (...)
#      <a href='file:///Users/aishwaryaharpale/opt/anaconda3/envs/moseq2-nlp/lib/python3.8/site-packages/numpy/core/_asarray.py?line=80'>81</a>
#      <a href='file:///Users/aishwaryaharpale/opt/anaconda3/envs/moseq2-nlp/lib/python3.8/site-packages/numpy/core/_asarray.py?line=81'>82</a>     """
# ---> <a href='file:///Users/aishwaryaharpale/opt/anaconda3/envs/moseq2-nlp/lib/python3.8/site-packages/numpy/core/_asarray.py?line=82'>83</a>     return array(a, dtype, copy=False, order=order)
#
# ValueError: could not convert string to float: '[0.02164686 0.03777589 0.02631579 0.02419355 0.02419355 0.03056027\n 0.03056027 0.03353141 0.02843803 0.01740238 0.02249576 0.01315789\n 0.02249576 0.01697793 0.01867572 0.02419355 0.03225806 0.0114601\n 0.02758913 0.02419355 0.01612903 0.0229202  0.00764007 0.00891341\n 0.02419355 0.01061121 0.024618   0.01103565 0.01994907 0.01485569\n 0.02249576 0.01103565 0.00594228 0.01400679 0.00891341 0.00933786\n 0.00551783 0.01740238 0.00636672 0.01697793 0.01443124 0.00636672\n 0.02079796 0.01061121 0.01315789 0.01061121 0.00382003 0.00424448\n 0.00466893 0.00466893 0.01061121 0.01018676 0.01103565 0.00679117\n 0.00212224 0.00848896 0.00976231 0.01188455 0.00594228 0.00339559\n 0.0008489  0.00594228 0.00297114 0.00424448 0.00466893 0.00806452\n 0.00891341 0.00551783 0.00254669 0.00594228 0.00976231]'

# %%
pca = PCA(n_components=3)
pca.fit(features)
pca_f = pca.transform(features)

fig = plt.figure(1,figsize=(6,5))
ax = Axes3D(fig, rect=[0, 0, 0.95, 1], elev=48, azim=134)

ax.scatter(pca_f[:, 0], pca_f[:, 1],pca_f[:, 2], c=c, cmap=plt.cm.nipy_spectral, edgecolor="k")

# %% [markdown]
# # gST

# %%
features = pd.read_csv('gST/features.csv').to_numpy()
labels = pd.read_csv('gST/labels.csv').to_numpy()

# %%
pca = PCA(n_components=2)
pca.fit(features)
pca_f = pca.transform(features)

fig = plt.figure(figsize=(6,5))
ax = plt.axes()


ax.scatter(pca_f[:, 0], pca_f[:, 1], c=c, cmap=plt.cm.nipy_spectral, edgecolor="k")

# %%
pca = PCA(n_components=3)
pca.fit(features)
pca_f = pca.transform(features)

fig = plt.figure(1,figsize=(6,5))
ax = Axes3D(fig, rect=[0, 0, 0.95, 1], elev=48, azim=134)

ax.scatter(pca_f[:, 0], pca_f[:, 1],pca_f[:, 2], c=c, cmap=plt.cm.nipy_spectral, edgecolor="k")
